# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
arr1=np.array([1,2,3,4,5,6])

# %%
arr2=np.array([2,4,5,7,6,2])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
arr2
# Out:
# array([2, 4, 5, 7, 6, 2])

# %%
plt.plot(arr1,arr2,)
plt.title("Shap")
plt.ylabel('year')
plt.xlabel('Size')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(arr1,arr2,)
plt.title("Shap")
plt.ylabel('year')
plt.xlabel('Size')

plt.subplot(1,2,2)
plt.plot(arr2,arr1,'yo--')
plt.title("Shap")
plt.ylabel('year')
plt.xlabel('Size')
plt.show()
plt.savefig('two graph')

# %%
#Bar plot
COMPANY_NAME=['nokia', 'Samsung','M9','Apple']
Market_Share=[8,25,1,5]
plt.bar(COMPANY_NAME,Market_Share)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(COMPANY_NAME,Market_Share)
plt.grid = (True)

# %%
plt.pie(arr2,labeld3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-7f07ec2dc58b> in <module>
# ----> 1 plt.pie(arr2,label(arr2))
#
# NameError: name 'label' is not defined
